# %%
import pandas as pd

uri = "https://raw.githubusercontent.com/murilocoura/ProjetoDataScience/master/Planilha%20sem%20t%C3%ADtulo%20-%20P%C3%A1gina1%20(2).csv"
pd.read_csv(uri)
# Out:
#     idjogo                                               jogo  nota
# 0        1                   Super Mario Galaxy 2 (Wii, 2010)    97
# 1        2  The Legend of Zelda: Breath of the Wild (Switc...    97
# 2        3        Red Dead Redemption 2 (PlayStation 4, 2018)    97
# 3        4           Grand Theft Auto V (PlayStation 4, 2014)    97
# 4        5                 Super Mario Odyssey (Switch, 2017)    97
# 5        6                     Mass Effect 2 (Xbox 360, 2010)    96
# 6        7       The Elder Scrolls V: Skyrim (Xbox 360, 2011)    96
# 7        8               The Last of Us (PlayStation 3, 2013)    95
# 8        9    The Last of Us Remastered (PlayStation 4, 2014)    95
# 9       10               Red Dead Redemption (Xbox 360, 2010)    95
# 10      11                          Portal 2 (Xbox 360, 2011)    95
# 11      12                   God of War (PlayStation 4, 2018)    94
# 12      13               Batman: Arkham City (Xbox 360, 2011)    94
# ...

# %%
import pandas as pd

notas = pd.read_csv("https://raw.githubusercontent.com/murilocoura/ProjetoDataScience/master/Planilha%20sem%20t%C3%ADtulo%20-%20P%C3%A1gina1%20(2).csv")
notas.head()
# Out:
#    idjogo                                               jogo  nota
# 0       1                   Super Mario Galaxy 2 (Wii, 2010)    97
# 1       2  The Legend of Zelda: Breath of the Wild (Switc...    97
# 2       3        Red Dead Redemption 2 (PlayStation 4, 2018)    97
# 3       4           Grand Theft Auto V (PlayStation 4, 2014)    97
# 4       5                 Super Mario Odyssey (Switch, 2017)    97

# %%
notas.shape
# Out:
# (50, 3)

# %%
notas['nota'].unique()
# Out:
# array([97, 96, 95, 94, 93, 92, 91])

# %%
notas['nota'].value_counts()
# Out:
# 92    16
# 93    13
# 91     6
# 97     5
# 95     4
# 94     4
# 96     2
# Name: nota, dtype: int64

# %%
print("Media", notas['nota'].mean())
print("Mediana", notas['nota'].median())
# Out:
# Media 93.2
# Mediana 93.0

# %%
notas.nota.head()
# Out:
# 0    97
# 1    97
# 2    97
# 3    97
# 4    97
# Name: nota, dtype: int64

# %%
notas.nota.plot(kind='hist')

# %%
notas.nota.describe
# Out:
# <bound method NDFrame.describe of 0     97
# 1     97
# 2     97
# 3     97
# 4     97
# 5     96
# 6     96
# 7     95
# 8     95
# 9     95
# 10    95
# 11    94
# 12    94
# 13    94
# 14    94
# 15    93
# 16    93
# 17    93
# 18    93
# 19    93
# 20    93
# 21    93
# 22    93
# 23    93
# 24    93
# 25    93
# 26    93
# 27    93
# 28    92
# 29    92
# 30    92
# 31    92
# 32    92
# 33    92
# 34    92
# 35    92
# 36    92
# 37    92
# 38    92
# 39    92
# 40    92
# 41    92
# 42    92
# 43    92
# 44    91
# 45    91
# 46    91
# 47    91
# 48    91
# 49    91
# Name: nota, dtype: int64>

# %%
notas.nota.describe()
# Out:
# count    50.000000
# mean     93.200000
# std       1.784285
# min      91.000000
# 25%      92.000000
# 50%      93.000000
# 75%      94.000000
# max      97.000000
# Name: nota, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-efecbb616273> in <module>
# ----> 1 import seaborn as sns
#       2 sns.boxplot(notas.nota)
#
# ModuleNotFoundError: No module named 'seaborn'
